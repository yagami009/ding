# %%
import json

with open('/Users/rishil/Desktop/FYP/EEG-decoding/log_data.json', 'r') as f:
  data = json.load(f)

print(len(data['7hz']))
print(len(data['10hz']))
print(len(data['12hz']))

# %%
import matplotlib.pyplot as plt

x = [i for i in range(len(data['7hz'][4]['eeg_data']))]

seven = data['7hz'][4]['eeg_data']
ten = data['10hz'][3]['eeg_data']
twelve = data['12hz'][2]['eeg_data']

plt.plot(x, seven) # plot first line
plt.plot(x,ten)
plt.plot(x,twelve)

print(min(seven),max(seven))
print(min(ten),max(ten))
print(min(twelve),max(twelve))
# Out:
# -903.2081 928.4754
# -1648.846 426.6218
# -2098.882 1336.039

# %%
from scipy.fft import fft, ifft
import math
import numpy as np

w7 = np.fft.fft(np.array(seven))
freqs7 = np.fft.fftfreq(len(np.array(seven)))

w10 = np.fft.fft(np.array(ten))
freqs10 = np.fft.fftfreq(len(np.array(ten)))

w12 = np.fft.fft(np.array(twelve))
freqs12 = np.fft.fftfreq(len(np.array(twelve)))

# %%
import numpy as np
stim_freqs = [7,10,12] # stim freqs used
fs = 64 # sampling freq
Ns = 256 # number of sample points to consider
Nh = 1 # number of harmonics for CCA-based algos

# %%
from eeg_lib.cca import CCA
cca = CCA(stim_freqs, Ns, Nh=Nh)
result = cca.classify(np.array(seven))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-62af6201c959> in <module>
#       1 from eeg_lib.cca import CCA
#       2 cca = CCA(stim_freqs, Ns, Nh=Nh)
# ----> 3 result = cca.classify(np.array(seven))
#
# ~/Desktop/FYP/EEG-decoding/eeg_lib/cca.py in classify(self, X_test, method)
#     307         )  # precompute data auto correlation matrix
#     308         for f in self.stim_freqs:
# --> 309             Y = cca_reference(
#     310                 [f], self.fs, len(X_test), Nh=self.Nh, standardise_out=True
#     311             )
#
# ~/Desktop/FYP/EEG-decoding/eeg_lib/cca.py in cca_reference(list_freqs, fs, Ns, Nh, standardise_out)
#     436     y_ref = np.squeeze(y_ref)
#     437     if standardise_out:  # zero mean, unit std. dev
# --> 438         return standardise(y_ref)
#     439     return y_ref
#     440
#
# ...
